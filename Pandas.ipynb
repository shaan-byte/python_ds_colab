# %% [markdown]
# <a href="https://colab.research.google.com/github/shaan-byte/python_ds_colab/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
good_standing_students=np.array([1,0,1])
percentages=np.array([[29,33,45],
                     [33,51,37],
                     [90,2,42],
                     [98,23,46]])
print(good_standing_students.shape)
print(percentages.shape)
# Out:
# (3,)
# (4, 3)

# %%
new=percentages*good_standing_students
new
# Out:
# array([[29,  0, 45],
#        [33,  0, 37],
#        [90,  0, 42],
#        [98,  0, 46]])

# %% [markdown]
# Pandas Series

# %%
marks=pd.Series(data=[20,30,34,40,50],index=['ram','shyam','bob','alice','kate'],name='marks1')
print(f"iloc using system index {marks.iloc[0]}")
print(f"loc using user index {marks.loc['shyam']}")
print(marks)
# Out:
# iloc using system index 20
# loc using user index 30
# ram      20
# shyam    30
# bob      34
# alice    40
# kate     50
# Name: marks1, dtype: int64

# %% [markdown]
# Dataframes

# %%
employee = {
    "Employee_ID": [101, 102, 103, 104],
    "Name": ["Amit", "Priya", "Rahul", "Neha"],
    "Department": ["HR", "IT", "Finance", "Marketing"],
    "Salary": [45000, 70000, 65000, 55000]
}

df = pd.DataFrame(employee) #Each column can have a differnet data type

print(df)
# Out:
#    Employee_ID   Name Department  Salary
# 0          101   Amit         HR   45000
# 1          102  Priya         IT   70000
# 2          103  Rahul    Finance   65000
# 3          104   Neha  Marketing   55000

# %% [markdown]
# Accesing columns

# %%
name_col=df['Name'] #single column accessing
print(f"The name column series \n {name_col}")

mul_col=df[['Name','Department','Salary']] #Multiple brackets for multiple Columns
print(f"<ultiple column name \n {mul_col}") #outer bracket for df inner bracket for the lists
# Out:
# The name column series
#  0     Amit
# 1    Priya
# 2    Rahul
# 3     Neha
# Name: Name, dtype: object
# <ultiple column name
#      Name Department  Salary
# 0   Amit         HR   45000
# 1  Priya         IT   70000
# 2  Rahul    Finance   65000
# 3   Neha  Marketing   55000

# %% [markdown]
# loc() and iloc()

# %%
#Acceesing elements

print("The 0th row \n")

print(df.loc[0]) #loc means the user speicfied lavel or index

print("The 1st row \n")

print(df.iloc[1])
# Out:
# The 0th row
#
# Employee_ID      101
# Name            Amit
# Department        HR
# Salary         45000
# Name: 0, dtype: object
# The 1st row
#
# Employee_ID      102
# Name           Priya
# Department        IT
# Salary         70000
# Name: 1, dtype: object

# %% [markdown]
# Row to Column access or vice versa

# %%
print(df.iloc[1]['Salary']) #print salary of the 1st postional index

print(df['Name'].loc[2]) #Give the name of the user with label index 2
# Out:
# 70000
# Rahul

# %% [markdown]
# Set index

# %%
df=df.set_index("Employee_ID")
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9039/1596621568.py in <cell line: 0>()
# ----> 1 df=df.set_index("Employee_ID")
#       2 print(df)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['Employee_ID'] are in the columns"

# %%
print(df)
# Out:
#               Name Department  Salary
# Employee_ID
# 101           Amit         HR   45000
# 102          Priya         IT   70000
# 103          Rahul    Finance   65000
# 104           Neha  Marketing   55000

# %% [markdown]
# Reading CSV file into dataframes

# %%
# Generate and save a realistic CSV file
# Students would normally receive this file from a data source or instructor
# We create it here so the notebook is self-contained

import csv, random
random.seed(42)

departments = ["Engineering", "Sales", "HR", "Finance"]
cities      = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Hyderabad"]
first_names = ["Ananya", "Rohit", "Priya", "Vikram", "Sneha", "Arjun",
               "Deepa", "Kiran", "Meera", "Suresh", "Lakshmi", "Rahul",
               "Divya", "Arun", "Pooja", "Sanjay", "Nisha", "Tarun"]
last_names  = ["Sharma", "Mehta", "Nair", "Rao", "Pillai", "Das",
               "Joshi", "Iyer", "Bose", "Kumar", "Reddy", "Singh"]

dept_salary_ranges = {
    "Engineering": (70000, 150000),
    "Sales":       (55000, 110000),
    "HR":          (50000,  95000),
    "Finance":     (65000, 130000),
}

rows = []
for i in range(50):
    emp_id  = 1001 + i
    name    = random.choice(first_names) + " " + random.choice(last_names)
    dept    = random.choice(departments)
    low, hi = dept_salary_ranges[dept]
    salary  = round(random.uniform(low, hi), -3)  # rounded to nearest 1000
    exp     = random.randint(1, 20)
    city    = random.choice(cities)
    perf    = round(random.uniform(2.0, 5.0), 1)  # performance rating
    year    = random.randint(2004, 2023)
    month   = random.randint(1, 12)
    join    = f"{year}-{month:02d}-01"
    active  = random.choice([True, True, True, False])  # 75% active

    # Introduce realistic messiness in ~15% of rows
    if random.random() < 0.08:
        salary = ""           # missing salary
    if random.random() < 0.08:
        perf = ""             # missing performance rating
    if random.random() < 0.06:
        dept = dept.lower()   # casing inconsistency

    rows.append([emp_id, name, dept, salary, exp, city, perf, join, active])

with open("employees.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["employee_id", "name", "department", "salary",
                     "experience", "city", "performance_rating", "join_date", "active"])
    writer.writerows(rows)

print("employees.csv created — 50 rows, 9 columns.")
print("Let's now load it with Pandas.")
# Out:
# employees.csv created — 50 rows, 9 columns.
# Let's now load it with Pandas.

# %% [markdown]
# Reading CSV

# %%
emp=pd.read_csv("employees.csv")
emp
# Out:
#     employee_id            name   department    salary  experience       city  \
# 0          1001   Vikram Sharma           HR       NaN           5     Mumbai
# 1          1002     Ananya Bose        Sales   94000.0          18    Chennai
# 2          1003      Meera Nair        Sales  108000.0          11     Mumbai
# 3          1004     Tarun Mehta      Finance   70000.0          10  Hyderabad
# 4          1005    Suresh Mehta        Sales  103000.0          13  Bangalore
# 5          1006     Priya Kumar        Sales   84000.0           8      Delhi
# 6          1007    Kiran Sharma           HR   68000.0           3      Delhi
# 7          1008      Pooja Nair           HR   56000.0          18  Hyderabad
# 8          1009    Sanjay Mehta  Engineering  139000.0           5      Delhi
# 9          1010      Meera Bose  Engineering  124000.0           4  Hyderabad
# 10         1011      Meera Bose        Sales   83000.0           4  Bangalore
# 11         1012    Nisha Sharma           HR   72000.0           4  Bangalore
# 12         1013    Sanjay Mehta        Sales   62000.0          16  Hyderabad
# 13         1014     Deepa Singh           HR   68000.0          12    Chennai
# 14         1015     Kiran Kumar        Sales   55000.0           2      Delhi
# 15         1016      Tarun Nair      Finance   81000.0          16    Chennai
# 16         1017     Rohit Reddy  Engineering   75000.0          11     Mumbai
# 17         1018      Priya Iyer  Engineering   74000.0          18     Mumbai
# 18         1019      Rohit Nair      Finance   65000.0          13  Bangalore
# 19         1020     Sanjay Nair        Sales       NaN           2  Hyderabad
# 20         1021      Nisha Nair  Engineering  147000.0           3      Delhi
# 21         1022     Rohit Kumar  Engineering  104000.0          19  Hyderabad
# 22         1023     Suresh Iyer           HR   92000.0           3     Mumbai
# 23         1024     Rahul Mehta        Sales   75000.0           6    Chennai
# 24         1025     Vikram Nair           HR   55000.0           4  Hyderabad
# 25         1026      Meera Bose      Finance   81000.0           2     Mumbai
# 26         1027     Arjun Singh      Finance  101000.0          14  Hyderabad
# 27         1028     Sneha Joshi        Sales   57000.0          12     Mumbai
# 28         1029      Arun Kumar        Sales  106000.0           8      Delhi
# 29         1030      Arun Reddy        Sales   70000.0           4    Chennai
# 30         1031       Kiran Rao  Engineering  123000.0          13  Bangalore
# 31         1032       Tarun Das  Engineering   79000.0           9      Delhi
# 32         1033      Arun Kumar  Engineering  101000.0          19      Delhi
# 33         1034   Lakshmi Kumar           HR   80000.0           4  Bangalore
# 34         1035     Divya Reddy        Sales   89000.0          10    Chennai
# 35         1036    Lakshmi Iyer      Finance   94000.0           7  Hyderabad
# 36         1037       Priya Rao           HR   60000.0           7      Delhi
# 37         1038      Divya Iyer      Finance       NaN           1     Mumbai
# 38         1039      Pooja Nair      Finance  108000.0          18  Hyderabad
# 39         1040     Sanjay Iyer           HR       NaN           9  Hyderabad
# 40         1041    Lakshmi Bose  Engineering   81000.0           8    Chennai
# 41         1042     Deepa Joshi      Finance       NaN          19     Mumbai
# 42         1043       Arun Bose        Sales   82000.0           9    Chennai
# 43         1044    Tarun Sharma      Finance       NaN           1     Mumbai
# 44         1045     Lakshmi Das      Finance   83000.0          14  Bangalore
# 45         1046    Rohit Sharma        Sales   66000.0           1  Hyderabad
# 46         1047      Rahul Nair  Engineering  132000.0           6  Bangalore
# 47         1048     Kiran Mehta           HR   88000.0          20     Mumbai
# 48         1049  Lakshmi Sharma      Finance  118000.0           4    Chennai
# 49         1050     Meera Kumar      Finance   95000.0          19  Bangalore
#
#     performance_rating   join_date  active
# 0                  4.0  2021-02-01   False
# 1                  2.7  2022-05-01    True
# 2                  2.3  2007-06-01    True
# 3                  NaN  2015-10-01    True
# 4                  3.4  2015-03-01    True
# 5                  3.4  2012-11-01    True
# 6                  4.7  2022-12-01    True
# 7                  2.8  2022-07-01   False
# 8                  4.4  2017-10-01    True
# 9                  4.3  2014-02-01    True
# 10                 4.5  2020-10-01    True
# 11                 4.6  2013-04-01    True
# 12                 2.5  2020-10-01   False
# 13                 4.7  2018-02-01    True
# 14                 2.2  2005-06-01    True
# 15                 2.6  2007-11-01   False
# 16                 2.7  2010-09-01   False
# 17                 4.9  2011-03-01   False
# 18                 4.8  2018-05-01   False
# 19                 4.2  2005-12-01    True
# 20                 2.2  2006-11-01    True
# 21                 3.6  2012-04-01    True
# 22                 3.4  2022-02-01    True
# 23                 4.5  2013-10-01    True
# 24                 2.5  2013-10-01    True
# 25                 3.9  2012-01-01    True
# 26                 2.0  2006-12-01    True
# 27                 4.7  2010-11-01    True
# 28                 4.9  2009-07-01    True
# 29                 4.6  2019-04-01    True
# 30                 2.8  2006-05-01    True
# 31                 3.7  2012-01-01    True
# 32                 NaN  2017-01-01    True
# 33                 3.5  2017-06-01   False
# 34                 3.6  2004-05-01    True
# 35                 3.4  2009-11-01    True
# 36                 2.1  2011-08-01    True
# 37                 4.3  2011-03-01   False
# 38                 3.0  2018-10-01   False
# 39                 3.5  2011-05-01   False
# 40                 4.1  2010-02-01   False
# 41                 4.6  2022-07-01   False
# 42                 3.5  2016-06-01   False
# 43                 3.9  2008-08-01    True
# 44                 4.5  2019-01-01    True
# 45                 2.5  2008-08-01    True
# 46                 2.3  2004-05-01   False
# 47                 4.4  2022-01-01    True
# 48                 4.9  2018-12-01    True
# 49                 3.0  2011-02-01    True

# %% [markdown]
# Boolean Indexing

# %%
high_earners=df['Salary']>60000
print(high_earners) #Returns true or false whose salary is greater than 60k

print(df[high_earners]) #give the rows where the conditions is satisfied
# Out:
# Employee_ID
# 101    False
# 102     True
# 103     True
# 104    False
# Name: Salary, dtype: bool
#               Name Department  Salary
# Employee_ID
# 102          Priya         IT   70000
# 103          Rahul    Finance   65000
